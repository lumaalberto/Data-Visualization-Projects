# %%
import numpy as np

# %%
import pandas as pd

from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#import hotdog contest winners

# %%
df = ("C:\\Users\\LumaA\PycharmProjects\Data Visualization\hotdog_contest_winners.csv")

# %%
Hotdogs_Contest = pd.read_csv(df)

# %%
print(Hotdogs_Contest)
# Out:
#     Year                        Winner  Dogs eaten        Country  New record
# 0   1980  Paul Siederman & Joe Baldini        9.10  United States           0
# 1   1981               Thomas DeBerry        11.00  United States           0
# 2   1982                Steven Abrams        11.00  United States           0
# 3   1983                  Luis Llamas        19.50         Mexico           0
# 4   1984                Birgit Felden         9.50        Germany           0
# 5   1985              Oscar Rodriguez        11.75  United States           0
# 6   1986                  Mark Heller        15.50  United States           0
# 7   1987                  Don Wolfman        12.00  United States           0
# 8   1988                    Jay Green        14.00  United States           0
# 9   1989                    Jay Green        13.00  United States           0
# 10  1990                  Mike DeVito        16.00  United States           0
# ...

# %%
ax = Hotdogs_Contest['Country'].value_counts().sort_index().plot(kind='bar', fontsize=14, figsize=(12,10))

# %%
ax = Hotdogs_Contest['Country'].value_counts().sort_index().plot(kind='pie', fontsize=14, figsize=(12,10))

# %%
#import hotdogs_places

# %%
df1 = ("C:\\Users\\LumaA\PycharmProjects\Data Visualization\hotdog_places.csv")

# %%
Hotdogs_Places = pd.read_csv(df1)

# %%
print(Hotdogs_Places)
# Out:
#    Year_2000  Year_2001  Year_2002  Year_2003  Year_2004  Year_2005  \
# 0         25       50.0       50.5       44.5       53.5         49
# 1         24       31.0       26.0       30.5       38.0         37
# 2         22       23.5       25.5       29.5       32.0         32
#
#    Year_2006  Year_2007  Year_2008  Year_2009  Year_2010
# 0         54         66         59       68.0         54
# 1         52         63         59       64.5         43
# 2         37         49         42       55.0         37

# %%
ax1 = Hotdogs_Places['Year_2000'].value_counts().sort_index().plot(kind='bar', fontsize=14, figsize=(12,10))

# %%
ax2 = Hotdogs_Places['Year_2005'].value_counts().sort_index().plot(kind='bar', fontsize=14, figsize=(12,10))

# %%
ax3 = Hotdogs_Places['Year_2010'].value_counts().sort_index().plot(kind='bar', fontsize=14, figsize=(12,10))

# %%
#import Obama approval rate

# %%
df2 = ("C:\\Users\\LumaA\PycharmProjects\Data Visualization\obama_approval_ratings.csv")

# %%
Obama_Approval_Ratings = pd.read_csv(df2)

# %%
print(Obama_Approval_Ratings)
# Out:
#                        Issue  Approve  Disapprove  None
# 0             Race Relations       52          38    10
# 1                  Education       49          40    11
# 2                  Terrorism       48          45     7
# 3              Energy Policy       47          42    11
# 4            Foreign Affairs       44          48     8
# 5                Environment       43          51     6
# 6          Situation in Iraq       41          53     6
# 7                      Taxes       41          54     5
# 8          Healthcare Policy       40          57     3
# 9                    Economy       38          59     3
# 10  Situation in Afghanistan       36          57     7
# 11    Federal Budget Deficit       31          64     5
# 12               Immigration       29          62     9

# %%
ax4 = Obama_Approval_Ratings['Approve'].value_counts().sort_index().plot(kind='bar', fontsize=14, figsize=(12,10))
